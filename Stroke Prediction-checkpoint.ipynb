# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('healthcare-dataset-stroke-data.csv')
data.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
data.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %%
attributes = ['age', 'avg_glucose_level','bmi']

# %%
data[attributes].hist(bins=50,figsize=(12,6))
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'avg_glucose_level'}>],
#        [<AxesSubplot:title={'center':'bmi'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
sns.countplot(x='gender',data=data,hue='stroke')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
data['gender'].value_counts()
# Out:
# Female    2994
# Male      2115
# Other        1
# Name: gender, dtype: int64

# %%
data['work_type'].value_counts()
# Out:
# Private          2925
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: work_type, dtype: int64

# %%
data['Residence_type'].value_counts()
# Out:
# Urban    2596
# Rural    2514
# Name: Residence_type, dtype: int64

# %%
sns.countplot(x='work_type',data=data,hue='stroke')
# Out:
# <AxesSubplot:xlabel='work_type', ylabel='count'>

# %%
sns.countplot(x='Residence_type',data=data,hue='heart_disease')
# Out:
# <AxesSubplot:xlabel='Residence_type', ylabel='count'>

# %%
sns.heatmap(data.isnull(),yticklabels=False,cmap='viridis',cbar=False)
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x='stroke',y='age',data=data)
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='age'>

# %%
data['age'].hist()
# Out:
# <AxesSubplot:>

# %%
cat = pd.cut(data.age, bins=[0,2,17,65,99], labels= ['baby','Child','Adult','Elderly'])
data.insert(2,'age_group',cat)

# %%
data
# Out:
#          id  gender age_group   age  hypertension  heart_disease ever_married  \
# 0      9046    Male   Elderly  67.0             0              1          Yes
# 1     51676  Female     Adult  61.0             0              0          Yes
# 2     31112    Male   Elderly  80.0             0              1          Yes
# 3     60182  Female     Adult  49.0             0              0          Yes
# 4      1665  Female   Elderly  79.0             1              0          Yes
# ...     ...     ...       ...   ...           ...            ...          ...
# 5105  18234  Female   Elderly  80.0             1              0          Yes
# 5106  44873  Female   Elderly  81.0             0              0          Yes
# 5107  19723  Female     Adult  35.0             0              0          Yes
# 5108  37544    Male     Adult  51.0             0              0          Yes
# 5109  44679  Female     Adult  44.0             0              0          Yes
#
# ...

# %%
data['age_group'].hist()
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='age_group',data=data,hue='stroke')
# Out:
# <AxesSubplot:xlabel='age_group', ylabel='count'>

# %%
sns.countplot(x='hypertension',data=data,hue='stroke')
# Out:
# <AxesSubplot:xlabel='hypertension', ylabel='count'>

# %%
sns.boxplot(data=data,x='stroke',y='age')
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='age'>

# %%
sns.displot(data['age'])

# %%
sns.countplot(x='ever_married',data=data,hue='stroke')
# Out:
# <AxesSubplot:xlabel='ever_married', ylabel='count'>

# %%
sns.distplot(data['a'])

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(data, data["stroke"]):
    strat_train_set = data.loc[train_index]
    strat_test_set = data.loc[test_index]

# %%
strat_test_set["stroke"].value_counts() / len(strat_test_set)
# Out:
# 0    0.951076
# 1    0.048924
# Name: stroke, dtype: float64

# %%
data["stroke"].value_counts() / len(data)
# Out:
# 0    0.951272
# 1    0.048728
# Name: stroke, dtype: float64

# %%
strat_train_set["stroke"].value_counts() / len(strat_train_set)
# Out:
# 0    0.951321
# 1    0.048679
# Name: stroke, dtype: float64

# %%
strat_train_set.head()
# Out:
#          id  gender age_group   age  hypertension  heart_disease ever_married  \
# 845   25283  Female     Adult  48.0             0              0          Yes
# 3744  43734    Male     Child  15.0             0              0           No
# 4183  47113  Female   Elderly  67.0             0              0          Yes
# 3409  56996    Male     Adult  44.0             0              0          Yes
# 284   26325    Male     Child  14.0             0              0           No
#
#           work_type Residence_type  avg_glucose_level   bmi smoking_status  \
# 845         Private          Urban              69.21  33.1   never smoked
# 3744        Private          Rural             122.25  21.0   never smoked
# 4183  Self-employed          Rural             110.42  24.9   never smoked
# 3409        Private          Urban              65.41  24.8         smokes
# 284        Govt_job          Urban              82.34  31.6        Unknown
#
#       stroke
# 845        0
# 3744       0
# ...

# %%
sns.countplot(x='age_group',data=strat_train_set,hue='stroke')
# Out:
# <AxesSubplot:xlabel='age_group', ylabel='count'>

# %%
data['smoking_status'].value_counts()
# Out:
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: smoking_status, dtype: int64

# %%
sns.countplot(x='smoking_status',data=data,hue='age_group')
# Out:
# <AxesSubplot:xlabel='smoking_status', ylabel='count'>
